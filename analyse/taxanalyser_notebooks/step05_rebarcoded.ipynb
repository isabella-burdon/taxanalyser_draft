# %%
import os
import argparse
import pandas as pd
import re

# parser = argparse.ArgumentParser(description='Quality check for the run.')
# parser.add_argument('--input_data_path', type=str, help='Path to the input data directory')
# parser.add_argument('--analysis_output_path', type=str, help='Name of the file')
# parser.add_argument('--ont_kit_name', type=str, help='Name of the ONT kit used for sequencing')
# parser.add_argument('--barcode_to_sample_sheet', type=str, help='Path to the barcode to sample mapping sheet (optional)', default=None)
# args = parser.parse_args()
# input_data_path = args.input_data_path
# analysis_output_path = args.analysis_output_path
# ont_kit_name = args.ont_kit_name
# barcode_to_sample_sheet = args.barcode_to_sample_sheet

input_data_path = "/Volumes/SSD07/ISMS_rawdata/L15_ISMS_B96"
analysis_output_path = "/Volumes/SSD07/ISMS_analysis/L15_ISMS_B96"
ont_kit_name = "SQK-NBD114-96"
barcode_to_sample_sheet = "../barcode_to_sample_sheets/ISMS_RUN15.xlsx"

# Read in the barcode to sample mapping sheet
barcode_to_sample_sheet_df = pd.read_excel(barcode_to_sample_sheet)

# get all run identifiers from the raw fastq files
raw_folders = [x for x in os.listdir(input_data_path) if not x.startswith('.')]

all_files_in_raw_folders = []

for folder in raw_folders:
    print(folder)
    base_dir = f"{input_data_path}/{folder}"
    subdirs = [d for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d))]
    if len(subdirs) == 1:
        folder_path = os.path.join(base_dir, subdirs[0], "fastq_pass")
    else:
        raise ValueError(f"Expected 1 subdir in {base_dir}, found {len(subdirs)}: {subdirs}")
    print(folder_path)
    for barcode_dir in os.listdir(folder_path):
        barcode_path = os.path.join(folder_path, barcode_dir)
        if os.path.isdir(barcode_path):
            file_list = [re.sub(r'(_\d+)?\.fastq(?:\.gz)?$', '', f) for f in os.listdir(barcode_path) if f.endswith(('.fastq', '.fastq.gz')) and not f.startswith('.')]
            all_files_in_raw_folders.extend(file_list)
all_files_in_raw_folders = sorted(set(all_files_in_raw_folders))

print(all_files_in_raw_folders)

df_rows = []
for this_file in all_files_in_raw_folders:
    row = this_file.split('_')
    df_rows = df_rows + [row]

header_names = ['flow_cell_number', 'read_status', 'ONT_barcode', 'runid_prefix', 'runid_suffix']
df_run_info = pd.DataFrame(df_rows, columns=header_names)
df_run_info['runid'] = df_run_info['runid_prefix'] + '_' + df_run_info['runid_suffix']

df_run_sample_info = pd.merge(
    df_run_info[['flow_cell_number', 'read_status', 'ONT_barcode', 'runid']],
    barcode_to_sample_sheet_df[['flow_cell_number', 'ONT_barcode', 'runid', 'sample_id']],
    left_on=['flow_cell_number', 'runid', 'ONT_barcode'],
    right_on=['flow_cell_number', 'runid', 'ONT_barcode'],
    how='inner'
)
df_run_sample_info['runid_prefix'] = [x.split('_')[0] for x in df_run_sample_info['runid']]

runid_to_flowcell_dict = (
    df_run_sample_info
    .groupby('runid_prefix')['flow_cell_number'].unique()
    .apply(list)
    .to_dict()
)

# helper to normalize '04' -> 'barcode04' to match your Excel
def _normalize_barcode(bc: str) -> str:
    bc = str(bc)
    return bc if bc.startswith('barcode') else f'barcode{bc}'

def rebarcode_files(analysis_output_path, ont_kit_name):

    host_depleted_dir=f"{analysis_output_path}/data/host_depleted"
    file_basename_list = sorted([f.split('/')[-1].split('_bacterial')[0] for f in os.listdir(host_depleted_dir) if f.endswith('_bacterial.fastq.gz')])
    output_dir=f"{analysis_output_path}/data/rebarcoded"

    # initialise shell script for dorado commands
    with open(f"dorado_commands_tmp.sh", 'w') as f:
        f.write("#!/bin/bash\n\n")

    for file_basename in file_basename_list:

        # DOUBLE END BARCODE
        working_dir=f"{output_dir}/both_ends/{file_basename}"
        os.makedirs(working_dir, exist_ok=True)
        command = f'dorado demux "{host_depleted_dir}/{file_basename}_bacterial.fastq.gz" -v -o "{working_dir}" --kit-name "{ont_kit_name}" --barcode-both-ends --emit-fastq --emit-summary'
        with open(f"dorado_commands_tmp.sh", 'a') as f:
            f.write(f"{command}\n")

        # SINGLE END BARCODE
        working_dir=f"{output_dir}/single_end/{file_basename}"
        os.makedirs(working_dir, exist_ok=True)
        command = f'dorado demux "{host_depleted_dir}/{file_basename}_bacterial.fastq.gz" -v -o "{working_dir}" --kit-name "{ont_kit_name}" --emit-fastq --emit-summary'
        with open(f"dorado_commands_tmp.sh", 'a') as f:
            f.write(f"{command}\n")

def process_rebarcoded_files(analysis_output_path, which_end):

    rebarcoded_dir=f"{analysis_output_path}/data/rebarcoded"

    which_path = f'{rebarcoded_dir}/{which_end}'
    if not os.path.isdir(which_path):
        print(f"{which_path} does not exist. Skipping {which_end}.")
        return

    file_basename_list = sorted([f for f in os.listdir(which_path) if not f.startswith('.')])

    for file_basename in file_basename_list:
        
        working_dir=f"{rebarcoded_dir}/{which_end}/{file_basename}"
        if not os.path.isdir(working_dir):  # FIX: guard stray files
            continue

        # FIX: accept both .fastq and .fastq.gz
        input_file_names = sorted([
            f for f in os.listdir(working_dir)
            if (f.endswith('.fastq') or f.endswith('.fastq.gz'))
        ])
        
        # extract and save info from the info txt file
        info_txt_path = f"{working_dir}/barcoding_summary.txt"
        info_txt_contents = []
        if os.path.exists(info_txt_path):
            with open(info_txt_path, 'r') as f:
                info_txt_contents = f.readlines()
        else:
            print(f"{info_txt_path} does not exist. Skipping info parsing.")
            # don't continue; still move/concat files

        loop_df = []
        for line in info_txt_contents[1:]:
            barcode_identity = line.split('.fastq')[0].split('_')[-1]
            read_identity = line.split('\t')[1]
            row = [read_identity, barcode_identity]
            loop_df.append(row)
        if loop_df:
            loop_df = pd.DataFrame(loop_df, columns=['read_identity', 'barcode_identity'])
            stats_dir = f"{analysis_output_path}/output/pipeline_stats/barcoding"
            os.makedirs(stats_dir, exist_ok=True)
            if which_end == 'both_ends':
                output_stats_dir = f"{stats_dir}/double_barcoding"
            else:
                output_stats_dir = f"{stats_dir}/single_barcoding"
            os.makedirs(output_stats_dir, exist_ok=True)
            loop_df.to_csv(f"{output_stats_dir}/{file_basename}_barcode_counts.csv", index=False)

        # rename and move unclassified files
        unclassified_file_names = [f for f in input_file_names if 'unclassified' in f]
        if len(unclassified_file_names) == 0:
            print(f"No unclassified files found for {file_basename}. Skipping concatenation.")
        else:
            run_id = unclassified_file_names[0].split('-')[0]
            flowcell_id = runid_to_flowcell_dict.get(run_id, [])[0]
            print(flowcell_id)
            raw_bc = file_basename.split('barcode')[-1].split('-')[-1].split('.')[0]
            print(raw_bc)
            barcode = _normalize_barcode(raw_bc)
            print(barcode)

            matches = df_run_sample_info.loc[
                (df_run_sample_info['flow_cell_number'] == flowcell_id) & 
                (df_run_sample_info['ONT_barcode'] == barcode), 'sample_id'
            ].values
            print(matches)

            if len(matches) > 0 and pd.notna(matches[0]):
                sample_id = str(matches[0])
            else:
                sample_id = f"unknown_{flowcell_id}-{barcode}"
                print(f"No sample_id match for flow_cell_number={flowcell_id}, barcode={barcode}. Using '{sample_id}'.")

            # FIX: preserve extension (.fastq or .fastq.gz) and concat safely
            out_ext = '.fastq.gz' if any(n.endswith('.gz') for n in unclassified_file_names) else '.fastq'
            out_path = f"{rebarcoded_dir}/unclassified-{which_end.replace('_', '-')}_{sample_id.replace('_', '-')}{out_ext}"
            if out_ext.endswith('.gz'):
                cmd = f"cat {' '.join([f'{working_dir}/{x}' for x in unclassified_file_names])} > {out_path}"
            else:
                cmd = f"cat {' '.join([f'{working_dir}/{x}' for x in unclassified_file_names])} > {out_path}"
            print(cmd)
            os.system(cmd)

        # rename and move classified files
        classified_file_names = [f for f in input_file_names if 'unclassified' not in f]
        if len(classified_file_names) == 0:
            print(f"No classified files found for {file_basename}. Skipping concatenation.")
        else:
            print(f"Processing classified files for {file_basename}...")
            for idx, input_file_name in enumerate(classified_file_names):
                run_id = input_file_name.split('_')[0][:8]
                flowcell_id_list = runid_to_flowcell_dict.get(run_id, [])
                flowcell_id = flowcell_id_list[0] if flowcell_id_list else None

                # last underscore token before extension -> 'barcode04'
                stem = input_file_name.rsplit('.', 1)[0]
                barcode = stem.split('_')[-1]
                barcode = _normalize_barcode(barcode)

                matches = df_run_sample_info.loc[
                    (df_run_sample_info['flow_cell_number'] == flowcell_id) & 
                    (df_run_sample_info['ONT_barcode'] == barcode), 'sample_id'
                ].values

                if len(matches) > 0 and pd.notna(matches[0]):
                    sample_id = str(matches[0])
                else:
                    sample_id = f"unknown_{flowcell_id}-{barcode}"
                    print(f"No sample_id match for flow_cell_number={flowcell_id}, barcode={barcode}. Using '{sample_id}'.")

                # FIX: preserve original extension
                ext = '.fastq.gz' if input_file_name.endswith('.gz') else '.fastq'
                output_file_name = f"classified_{which_end.replace('_', '-')}_{sample_id.replace('_', '-')}_{flowcell_id}-{barcode}_n{idx}.fastq"
                input_file_path = f"{working_dir}/{input_file_name}"
                output_file_path = f"{rebarcoded_dir}/{which_end}/{output_file_name}"
                command = f"mv {input_file_path} {output_file_path}"
                print(command)
                os.system(command)

    # make dictionary of existing files to match by sample ID
    classified_existing_files = [
        f for f in os.listdir(f"{rebarcoded_dir}/{which_end}/")
        if not f.startswith('.') and 'unclassified' not in f and (f.endswith('.fastq') or f.endswith('.fastq.gz'))]

    classified_existing_files_dict = {}
    for existing_file in classified_existing_files:
        sample_id = existing_file.split('_')[2]
        classified_existing_files_dict.setdefault(sample_id, []).append(existing_file)

    # concatenate classified files based on sample ID
    for sample_id, items_files in classified_existing_files_dict.items():
        out_ext = '.fastq.gz' if any(x.endswith('.gz') for x in items_files) else '.fastq'
        output_file_name = f"classified-{which_end}_{sample_id}{out_ext}"
        cmd = f"cat {' '.join([f'{rebarcoded_dir}/{which_end}/{x}' for x in items_files])} > {rebarcoded_dir}/{output_file_name}"
        print(cmd)
        os.system(cmd)

    command = f"rm -rf {rebarcoded_dir}/{which_end}"
    print(command)
    os.system(command)

rebarcode_files(analysis_output_path, ont_kit_name)
shell_script_path = 'dorado_commands_tmp.sh'
os.system(f"chmod +x {shell_script_path}")
os.system(f"./{shell_script_path}")
os.system(f"rm {shell_script_path}")

process_rebarcoded_files(analysis_output_path, 'both_ends')
process_rebarcoded_files(analysis_output_path, 'single_end')

# remove all unclassified single-end files
single_unclassified_files = [f for f in os.listdir(f"{analysis_output_path}/data/rebarcoded") if f.startswith('unclassified-single-end') and (f.endswith('.fastq') or f.endswith('.fastq.gz')) and not f.startswith('.')]
for f in single_unclassified_files:
    os.remove(f"{analysis_output_path}/data/rebarcoded/{f}")
# Out:
# startdate_10102025
# /Volumes/SSD07/ISMS_rawdata/L15_ISMS_B96/startdate_10102025/20251010_2245_P2S-01208-A_PBE82130_4e7bdd4f/fastq_pass
# ['PBE82130_pass_barcode01_4e7bdd4f_833498a8', 'PBE82130_pass_barcode02_4e7bdd4f_833498a8', 'PBE82130_pass_barcode03_4e7bdd4f_833498a8', 'PBE82130_pass_barcode04_4e7bdd4f_833498a8', 'PBE82130_pass_barcode05_4e7bdd4f_833498a8', 'PBE82130_pass_barcode06_4e7bdd4f_833498a8', 'PBE82130_pass_barcode07_4e7bdd4f_833498a8', 'PBE82130_pass_barcode08_4e7bdd4f_833498a8', 'PBE82130_pass_barcode09_4e7bdd4f_833498a8', 'PBE82130_pass_barcode10_4e7bdd4f_833498a8', 'PBE82130_pass_barcode11_4e7bdd4f_833498a8', 'PBE82130_pass_barcode12_4e7bdd4f_833498a8', 'PBE82130_pass_barcode13_4e7bdd4f_833498a8', 'PBE82130_pass_barcode14_4e7bdd4f_833498a8', 'PBE82130_pass_barcode15_4e7bdd4f_833498a8', 'PBE82130_pass_barcode16_4e7bdd4f_833498a8', 'PBE82130_pass_barcode17_4e7bdd4f_833498a8', 'PBE82130_pass_barcode18_4e7bdd4f_833498a8', 'PBE82130_pass_barcode19_4e7bdd4f_833498a8', 'PBE82130_pass_barcode20_4e7bdd4f_833498a8', 'PBE82130_pass_barcode21_4e7bdd4f_833498a8', 'PBE82130_pass_barcode22_4e7bdd4f_833498a8', 'PBE82130_pass_barcode23_4e7bdd4f_833498a8', 'PBE82130_pass_barcode24_4e7bdd4f_833498a8', 'PBE82130_pass_barcode25_4e7bdd4f_833498a8', 'PBE82130_pass_barcode26_4e7bdd4f_833498a8', 'PBE82130_pass_barcode27_4e7bdd4f_833498a8', 'PBE82130_pass_barcode28_4e7bdd4f_833498a8', 'PBE82130_pass_barcode29_4e7bdd4f_833498a8', 'PBE82130_pass_barcode30_4e7bdd4f_833498a8', 'PBE82130_pass_barcode31_4e7bdd4f_833498a8',
# > Output records written: 56
# PBE82130
# 04
# barcode04
# ['RUN15_S01_AH15']
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode01-04/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_unclassified.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/unclassified-both-ends_RUN15-S01-AH15.fastq
# Processing classified files for barcode01-04...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode01-04/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode02.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S01-AH15_PBE82130-barcode02_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode01-04/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode03.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S01-AH15_PBE82130-barcode03_n1.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode01-04/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode04.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S01-AH15_PBE82130-barcode04_n2.fastq
# PBE82130
# 08
# barcode08
# ['RUN15_S02_AU12']
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode05-08/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_unclassified.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/unclassified-both-ends_RUN15-S02-AU12.fastq
# Processing classified files for barcode05-08...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode05-08/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode05.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S02-AU12_PBE82130-barcode05_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode05-08/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode06.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S02-AU12_PBE82130-barcode06_n1.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode05-08/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode07.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S02-AU12_PBE82130-barcode07_n2.fastq
# PBE82130
# 12
# barcode12
# ['RUN15_S03_AQ07']
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode09-12/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_unclassified.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/unclassified-both-ends_RUN15-S03-AQ07.fastq
# Processing classified files for barcode09-12...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode09-12/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode09.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S03-AQ07_PBE82130-barcode09_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode09-12/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode11.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S03-AQ07_PBE82130-barcode11_n1.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode09-12/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode12.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S03-AQ07_PBE82130-barcode12_n2.fastq
# PBE82130
# 16
# barcode16
# ['RUN15_S04_AW18']
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode13-16/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_unclassified.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/unclassified-both-ends_RUN15-S04-AW18.fastq
# Processing classified files for barcode13-16...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode13-16/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode13.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S04-AW18_PBE82130-barcode13_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode13-16/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode14.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S04-AW18_PBE82130-barcode14_n1.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode13-16/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode15.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S04-AW18_PBE82130-barcode15_n2.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode13-16/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode16.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S04-AW18_PBE82130-barcode16_n3.fastq
# PBE82130
# 20
# barcode20
# ['RUN15_S05_AE10']
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode17-20/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_unclassified.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/unclassified-both-ends_RUN15-S05-AE10.fastq
# Processing classified files for barcode17-20...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode17-20/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode17.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S05-AE10_PBE82130-barcode17_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode17-20/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode19.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S05-AE10_PBE82130-barcode19_n1.fastq
# PBE82130
# 24
# barcode24
# ['RUN15_S06_AM26']
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode21-24/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_unclassified.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/unclassified-both-ends_RUN15-S06-AM26.fastq
# Processing classified files for barcode21-24...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode21-24/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode21.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S06-AM26_PBE82130-barcode21_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode21-24/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode22.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S06-AM26_PBE82130-barcode22_n1.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode21-24/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode23.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S06-AM26_PBE82130-barcode23_n2.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode21-24/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode24.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S06-AM26_PBE82130-barcode24_n3.fastq
# PBE82130
# 28
# barcode28
# ['RUN15_S07_AU15']
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode25-28/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_unclassified.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/unclassified-both-ends_RUN15-S07-AU15.fastq
# Processing classified files for barcode25-28...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode25-28/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode25.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S07-AU15_PBE82130-barcode25_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode25-28/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode26.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S07-AU15_PBE82130-barcode26_n1.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode25-28/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode27.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S07-AU15_PBE82130-barcode27_n2.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode25-28/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode28.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S07-AU15_PBE82130-barcode28_n3.fastq
# PBE82130
# 32
# barcode32
# ['RUN15_S08_AH01']
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode29-32/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_unclassified.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/unclassified-both-ends_RUN15-S08-AH01.fastq
# Processing classified files for barcode29-32...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode29-32/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode29.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S08-AH01_PBE82130-barcode29_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode29-32/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode31.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S08-AH01_PBE82130-barcode31_n1.fastq
# PBE82130
# 36
# barcode36
# ['RUN15_S09_AQ01']
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode33-36/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_unclassified.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/unclassified-both-ends_RUN15-S09-AQ01.fastq
# Processing classified files for barcode33-36...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode33-36/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode33.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S09-AQ01_PBE82130-barcode33_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode33-36/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode35.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S09-AQ01_PBE82130-barcode35_n1.fastq
# PBE82130
# 40
# barcode40
# ['RUN15_S10_AE09']
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode37-40/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_unclassified.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/unclassified-both-ends_RUN15-S10-AE09.fastq
# Processing classified files for barcode37-40...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode37-40/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode38.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S10-AE09_PBE82130-barcode38_n0.fastq
# PBE82130
# 44
# barcode44
# ['RUN15_S11_AE12']
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode41-44/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_unclassified.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/unclassified-both-ends_RUN15-S11-AE12.fastq
# Processing classified files for barcode41-44...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode41-44/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode41.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S11-AE12_PBE82130-barcode41_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode41-44/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode42.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S11-AE12_PBE82130-barcode42_n1.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode41-44/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode43.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S11-AE12_PBE82130-barcode43_n2.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode41-44/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode44.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S11-AE12_PBE82130-barcode44_n3.fastq
# PBE82130
# 48
# barcode48
# ['RUN15_S12_AQ05']
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode45-48/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_unclassified.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/unclassified-both-ends_RUN15-S12-AQ05.fastq
# No classified files found for barcode45-48. Skipping concatenation.
# PBE82130
# 52
# barcode52
# ['RUN15_S13_AE08']
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode49-52/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_unclassified.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/unclassified-both-ends_RUN15-S13-AE08.fastq
# Processing classified files for barcode49-52...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode49-52/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode49.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S13-AE08_PBE82130-barcode49_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode49-52/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode50.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S13-AE08_PBE82130-barcode50_n1.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode49-52/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode51.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S13-AE08_PBE82130-barcode51_n2.fastq
# PBE82130
# 56
# barcode56
# ['RUN15_S14_AQ08']
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode53-56/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_unclassified.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/unclassified-both-ends_RUN15-S14-AQ08.fastq
# Processing classified files for barcode53-56...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode53-56/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode53.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S14-AQ08_PBE82130-barcode53_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode53-56/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode54.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S14-AQ08_PBE82130-barcode54_n1.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode53-56/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode55.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S14-AQ08_PBE82130-barcode55_n2.fastq
# PBE82130
# 60
# barcode60
# ['RUN15_S15_AQ09']
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode57-60/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_unclassified.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/unclassified-both-ends_RUN15-S15-AQ09.fastq
# Processing classified files for barcode57-60...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode57-60/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode57.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S15-AQ09_PBE82130-barcode57_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode57-60/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode58.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S15-AQ09_PBE82130-barcode58_n1.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode57-60/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode59.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S15-AQ09_PBE82130-barcode59_n2.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode57-60/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode60.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S15-AQ09_PBE82130-barcode60_n3.fastq
# PBE82130
# 64
# barcode64
# ['RUN15_S16_AW20']
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode61-64/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_unclassified.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/unclassified-both-ends_RUN15-S16-AW20.fastq
# Processing classified files for barcode61-64...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode61-64/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode61.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S16-AW20_PBE82130-barcode61_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode61-64/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode62.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S16-AW20_PBE82130-barcode62_n1.fastq
# PBE82130
# 68
# barcode68
# ['RUN15_S17_AQ03']
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode65-68/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_unclassified.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/unclassified-both-ends_RUN15-S17-AQ03.fastq
# Processing classified files for barcode65-68...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode65-68/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode65.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S17-AQ03_PBE82130-barcode65_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode65-68/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode66.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S17-AQ03_PBE82130-barcode66_n1.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode65-68/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode67.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S17-AQ03_PBE82130-barcode67_n2.fastq
# PBE82130
# 72
# barcode72
# ['RUN15_S18_AW19']
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode69-72/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_unclassified.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/unclassified-both-ends_RUN15-S18-AW19.fastq
# Processing classified files for barcode69-72...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode69-72/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode69.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S18-AW19_PBE82130-barcode69_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode69-72/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode70.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S18-AW19_PBE82130-barcode70_n1.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode69-72/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode72.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S18-AW19_PBE82130-barcode72_n2.fastq
# PBE82130
# 76
# barcode76
# ['RUN15_S19_AW17']
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode73-76/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_unclassified.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/unclassified-both-ends_RUN15-S19-AW17.fastq
# Processing classified files for barcode73-76...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode73-76/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode73.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S19-AW17_PBE82130-barcode73_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode73-76/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode74.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S19-AW17_PBE82130-barcode74_n1.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode73-76/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode75.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S19-AW17_PBE82130-barcode75_n2.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode73-76/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode76.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S19-AW17_PBE82130-barcode76_n3.fastq
# PBE82130
# 80
# barcode80
# ['RUN15_S20_AJ29']
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode77-80/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_unclassified.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/unclassified-both-ends_RUN15-S20-AJ29.fastq
# Processing classified files for barcode77-80...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode77-80/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode77.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S20-AJ29_PBE82130-barcode77_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode77-80/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode78.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S20-AJ29_PBE82130-barcode78_n1.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode77-80/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode79.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S20-AJ29_PBE82130-barcode79_n2.fastq
# PBE82130
# 84
# barcode84
# ['RUN15_S21_AG22']
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode81-84/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_unclassified.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/unclassified-both-ends_RUN15-S21-AG22.fastq
# Processing classified files for barcode81-84...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode81-84/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode82.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S21-AG22_PBE82130-barcode82_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode81-84/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode83.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S21-AG22_PBE82130-barcode83_n1.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode81-84/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode84.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S21-AG22_PBE82130-barcode84_n2.fastq
# PBE82130
# 88
# barcode88
# ['RUN15_S22_AQ28']
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode85-88/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_unclassified.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/unclassified-both-ends_RUN15-S22-AQ28.fastq
# Processing classified files for barcode85-88...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode85-88/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode88.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S22-AQ28_PBE82130-barcode88_n0.fastq
# PBE82130
# 92
# barcode92
# ['RUN15_S23_AH19']
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode89-92/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_unclassified.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/unclassified-both-ends_RUN15-S23-AH19.fastq
# Processing classified files for barcode89-92...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode89-92/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode89.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S23-AH19_PBE82130-barcode89_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode89-92/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode90.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S23-AH19_PBE82130-barcode90_n1.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode89-92/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode91.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S23-AH19_PBE82130-barcode91_n2.fastq
# /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/barcode93-96/barcoding_summary.txt does not exist. Skipping info parsing.
# No unclassified files found for barcode93-96. Skipping concatenation.
# No classified files found for barcode93-96. Skipping concatenation.
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S01-AH15_PBE82130-barcode02_n0.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S01-AH15_PBE82130-barcode03_n1.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S01-AH15_PBE82130-barcode04_n2.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/classified-both_ends_RUN15-S01-AH15.fastq
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S02-AU12_PBE82130-barcode05_n0.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S02-AU12_PBE82130-barcode06_n1.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S02-AU12_PBE82130-barcode07_n2.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/classified-both_ends_RUN15-S02-AU12.fastq
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S03-AQ07_PBE82130-barcode09_n0.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S03-AQ07_PBE82130-barcode11_n1.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S03-AQ07_PBE82130-barcode12_n2.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/classified-both_ends_RUN15-S03-AQ07.fastq
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S04-AW18_PBE82130-barcode13_n0.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S04-AW18_PBE82130-barcode14_n1.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S04-AW18_PBE82130-barcode15_n2.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S04-AW18_PBE82130-barcode16_n3.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/classified-both_ends_RUN15-S04-AW18.fastq
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S05-AE10_PBE82130-barcode17_n0.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S05-AE10_PBE82130-barcode19_n1.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/classified-both_ends_RUN15-S05-AE10.fastq
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S06-AM26_PBE82130-barcode21_n0.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S06-AM26_PBE82130-barcode22_n1.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S06-AM26_PBE82130-barcode23_n2.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S06-AM26_PBE82130-barcode24_n3.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/classified-both_ends_RUN15-S06-AM26.fastq
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S07-AU15_PBE82130-barcode25_n0.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S07-AU15_PBE82130-barcode26_n1.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S07-AU15_PBE82130-barcode27_n2.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S07-AU15_PBE82130-barcode28_n3.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/classified-both_ends_RUN15-S07-AU15.fastq
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S08-AH01_PBE82130-barcode29_n0.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S08-AH01_PBE82130-barcode31_n1.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/classified-both_ends_RUN15-S08-AH01.fastq
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S09-AQ01_PBE82130-barcode33_n0.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S09-AQ01_PBE82130-barcode35_n1.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/classified-both_ends_RUN15-S09-AQ01.fastq
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S10-AE09_PBE82130-barcode38_n0.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/classified-both_ends_RUN15-S10-AE09.fastq
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S11-AE12_PBE82130-barcode41_n0.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S11-AE12_PBE82130-barcode42_n1.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S11-AE12_PBE82130-barcode43_n2.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S11-AE12_PBE82130-barcode44_n3.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/classified-both_ends_RUN15-S11-AE12.fastq
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S13-AE08_PBE82130-barcode49_n0.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S13-AE08_PBE82130-barcode50_n1.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S13-AE08_PBE82130-barcode51_n2.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/classified-both_ends_RUN15-S13-AE08.fastq
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S14-AQ08_PBE82130-barcode53_n0.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S14-AQ08_PBE82130-barcode54_n1.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S14-AQ08_PBE82130-barcode55_n2.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/classified-both_ends_RUN15-S14-AQ08.fastq
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S15-AQ09_PBE82130-barcode57_n0.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S15-AQ09_PBE82130-barcode58_n1.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S15-AQ09_PBE82130-barcode59_n2.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S15-AQ09_PBE82130-barcode60_n3.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/classified-both_ends_RUN15-S15-AQ09.fastq
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S16-AW20_PBE82130-barcode61_n0.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S16-AW20_PBE82130-barcode62_n1.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/classified-both_ends_RUN15-S16-AW20.fastq
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S17-AQ03_PBE82130-barcode65_n0.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S17-AQ03_PBE82130-barcode66_n1.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S17-AQ03_PBE82130-barcode67_n2.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/classified-both_ends_RUN15-S17-AQ03.fastq
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S18-AW19_PBE82130-barcode69_n0.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S18-AW19_PBE82130-barcode70_n1.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S18-AW19_PBE82130-barcode72_n2.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/classified-both_ends_RUN15-S18-AW19.fastq
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S19-AW17_PBE82130-barcode73_n0.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S19-AW17_PBE82130-barcode74_n1.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S19-AW17_PBE82130-barcode75_n2.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S19-AW17_PBE82130-barcode76_n3.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/classified-both_ends_RUN15-S19-AW17.fastq
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S20-AJ29_PBE82130-barcode77_n0.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S20-AJ29_PBE82130-barcode78_n1.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S20-AJ29_PBE82130-barcode79_n2.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/classified-both_ends_RUN15-S20-AJ29.fastq
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S21-AG22_PBE82130-barcode82_n0.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S21-AG22_PBE82130-barcode83_n1.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S21-AG22_PBE82130-barcode84_n2.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/classified-both_ends_RUN15-S21-AG22.fastq
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S22-AQ28_PBE82130-barcode88_n0.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/classified-both_ends_RUN15-S22-AQ28.fastq
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S23-AH19_PBE82130-barcode89_n0.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S23-AH19_PBE82130-barcode90_n1.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends/classified_both-ends_RUN15-S23-AH19_PBE82130-barcode91_n2.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/classified-both_ends_RUN15-S23-AH19.fastq
# rm -rf /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/both_ends
# No unclassified files found for barcode01-04. Skipping concatenation.
# Processing classified files for barcode01-04...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode01-04/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode02.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S01-AH15_PBE82130-barcode02_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode01-04/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode03.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S01-AH15_PBE82130-barcode03_n1.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode01-04/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode04.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S01-AH15_PBE82130-barcode04_n2.fastq
# No unclassified files found for barcode05-08. Skipping concatenation.
# Processing classified files for barcode05-08...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode05-08/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode05.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S02-AU12_PBE82130-barcode05_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode05-08/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode06.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S02-AU12_PBE82130-barcode06_n1.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode05-08/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode07.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S02-AU12_PBE82130-barcode07_n2.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode05-08/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode08.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S02-AU12_PBE82130-barcode08_n3.fastq
# No unclassified files found for barcode09-12. Skipping concatenation.
# Processing classified files for barcode09-12...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode09-12/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode09.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S03-AQ07_PBE82130-barcode09_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode09-12/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode10.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S03-AQ07_PBE82130-barcode10_n1.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode09-12/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode11.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S03-AQ07_PBE82130-barcode11_n2.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode09-12/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode12.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S03-AQ07_PBE82130-barcode12_n3.fastq
# No unclassified files found for barcode13-16. Skipping concatenation.
# Processing classified files for barcode13-16...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode13-16/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode13.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S04-AW18_PBE82130-barcode13_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode13-16/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode14.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S04-AW18_PBE82130-barcode14_n1.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode13-16/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode15.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S04-AW18_PBE82130-barcode15_n2.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode13-16/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode16.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S04-AW18_PBE82130-barcode16_n3.fastq
# No unclassified files found for barcode17-20. Skipping concatenation.
# Processing classified files for barcode17-20...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode17-20/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode17.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S05-AE10_PBE82130-barcode17_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode17-20/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode18.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S05-AE10_PBE82130-barcode18_n1.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode17-20/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode19.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S05-AE10_PBE82130-barcode19_n2.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode17-20/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode20.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S05-AE10_PBE82130-barcode20_n3.fastq
# No unclassified files found for barcode21-24. Skipping concatenation.
# Processing classified files for barcode21-24...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode21-24/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode21.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S06-AM26_PBE82130-barcode21_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode21-24/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode22.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S06-AM26_PBE82130-barcode22_n1.fastq
# ...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode81-84/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode84.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S21-AG22_PBE82130-barcode84_n2.fastq
# No unclassified files found for barcode85-88. Skipping concatenation.
# Processing classified files for barcode85-88...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode85-88/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode87.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S22-AQ28_PBE82130-barcode87_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode85-88/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode88.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S22-AQ28_PBE82130-barcode88_n1.fastq
# No unclassified files found for barcode89-92. Skipping concatenation.
# Processing classified files for barcode89-92...
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode89-92/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode89.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S23-AH19_PBE82130-barcode89_n0.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode89-92/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode90.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S23-AH19_PBE82130-barcode90_n1.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode89-92/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode91.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S23-AH19_PBE82130-barcode91_n2.fastq
# mv /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode89-92/4e7bdd4f-5c6d-453e-baa2-7927236db5f5_SQK-NBD114-96_barcode92.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S23-AH19_PBE82130-barcode92_n3.fastq
# /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/barcode93-96/barcoding_summary.txt does not exist. Skipping info parsing.
# No unclassified files found for barcode93-96. Skipping concatenation.
# No classified files found for barcode93-96. Skipping concatenation.
# cat /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S01-AH15_PBE82130-barcode02_n0.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S01-AH15_PBE82130-barcode03_n1.fastq /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/single_end/classified_single-end_RUN15-S01-AH15_PBE82130-barcode04_n2.fastq > /Volumes/SSD07/ISMS_analysis/L15_ISMS_B96/data/rebarcoded/classified-single_end_RUN15-